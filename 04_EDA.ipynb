# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load Cleaned Dataset
df = pd.read_csv("Job_Placement_Data_Enhanced.csv")

print("Dataset Shape:", df.shape)
# Out:
# Dataset Shape: (215, 20)

# %%
# Descriptive Statistics
print("\nStatistical Summary:")
print(df.describe())
# Out:
# Statistical Summary:
#        ssc_percentage  hsc_percentage  degree_percentage  emp_test_percentage  \
# count      215.000000      215.000000         215.000000           215.000000
# mean        67.303395       66.333163          66.370186            72.100558
# std         10.827205       10.897509           7.358743            13.275956
# min         40.890000       37.000000          50.000000            50.000000
# 25%         60.600000       60.900000          61.000000            60.000000
# 50%         67.000000       65.000000          66.000000            71.000000
# 75%         75.700000       73.000000          72.000000            83.500000
# max         89.400000       97.700000          91.000000            98.000000
#
#        mba_percent  years_experience  skills_match_percent  \
# count   215.000000        215.000000            215.000000
# mean     62.278186          2.483721             70.413953
# std       5.833385          1.701694             17.235065
# min      51.210000          0.000000             40.000000
# 25%      57.945000          1.000000             58.000000
# 50%      62.000000          3.000000             71.000000
# 75%      66.255000          4.000000             86.000000
# max      77.890000          5.000000             99.000000
#
#        num_certifications  internship_completed  interview_score
# count          215.000000            215.000000       215.000000
# mean             2.423256              0.483721        74.046512
# std              1.708259              0.500901        14.602447
# min              0.000000              0.000000        50.000000
# 25%              1.000000              0.000000        62.500000
# 50%              3.000000              0.000000        74.000000
# 75%              4.000000              1.000000        86.000000
# max              5.000000              1.000000        99.000000

# %%
print("\nCorrelation Matrix:")
print(df.corr(numeric_only=True))
# Out:
# Correlation Matrix:
#                       ssc_percentage  hsc_percentage  degree_percentage  \
# ssc_percentage              1.000000        0.511472           0.538404
# hsc_percentage              0.511472        1.000000           0.434206
# degree_percentage           0.538404        0.434206           1.000000
# emp_test_percentage         0.261993        0.245113           0.224470
# mba_percent                 0.388478        0.354823           0.402364
# years_experience           -0.120834       -0.057231          -0.090828
# skills_match_percent        0.046268        0.089996          -0.018565
# num_certifications          0.009290        0.028499           0.050025
# internship_completed       -0.034028       -0.039969          -0.010648
# interview_score            -0.020681        0.019731          -0.016472
#
#                       emp_test_percentage  mba_percent  years_experience  \
# ssc_percentage                   0.261993     0.388478         -0.120834
# hsc_percentage                   0.245113     0.354823         -0.057231
# degree_percentage                0.224470     0.402364         -0.090828
# emp_test_percentage              1.000000     0.218055         -0.013711
# mba_percent                      0.218055     1.000000          0.020971
# years_experience                -0.013711     0.020971          1.000000
# skills_match_percent             0.132357    -0.045345          0.026440
# num_certifications               0.022984     0.068889         -0.094872
# internship_completed            -0.014024     0.076426         -0.001683
# interview_score                 -0.045457    -0.065814         -0.093243
#
#                       skills_match_percent  num_certifications  \
# ssc_percentage                    0.046268            0.009290
# hsc_percentage                    0.089996            0.028499
# degree_percentage                -0.018565            0.050025
# emp_test_percentage               0.132357            0.022984
# mba_percent                      -0.045345            0.068889
# years_experience                  0.026440           -0.094872
# skills_match_percent              1.000000           -0.055974
# num_certifications               -0.055974            1.000000
# internship_completed             -0.065522           -0.043790
# interview_score                   0.038506           -0.044441
#
#                       internship_completed  interview_score
# ssc_percentage                   -0.034028        -0.020681
# hsc_percentage                   -0.039969         0.019731
# degree_percentage                -0.010648        -0.016472
# emp_test_percentage              -0.014024        -0.045457
# mba_percent                       0.076426        -0.065814
# years_experience                 -0.001683        -0.093243
# skills_match_percent             -0.065522         0.038506
# num_certifications               -0.043790        -0.044441
# internship_completed              1.000000        -0.138530
# interview_score                  -0.138530         1.000000

# %%
# Visualization 1 – Distribution of Numerical Features
df.hist(figsize=(12, 8))
plt.tight_layout()
plt.show()

# %%
# Visualization 2 – Correlation Heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
print("EDA Completed Successfully!")
# Out:
# EDA Completed Successfully!
